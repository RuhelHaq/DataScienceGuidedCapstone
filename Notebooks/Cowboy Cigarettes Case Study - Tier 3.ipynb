# %% [markdown]
# # Springboard Time Series - 'Cowboy Cigarettes' Case Study - Tier 3

# %% [markdown]
# ## Brief
#
# You're working in the US federal government as a data scientist in the Health and Environment department. You've been tasked with determining whether sales for the oldest and most powerful producers of cigarettes in the country are increasing or declining.
#
# **Cowboy Cigarettes (TM, *est.* 1890)** is the US's longest-running cigarette manufacturer. Like many cigarette companies, however, they haven't always been that public about their sales and marketing data. The available post-war historical data runs for only 11 years after they resumed production in 1949; stopping in 1960 before resuming again in 1970. Your job is to use the 1949-1960 data to predict whether the manufacturer's cigarette sales actually increased, decreased, or stayed the same. You need to make a probable reconstruction of the sales record of the manufacturer - predicting the future, from the perspective of the past - to contribute to a full report on US public health in relation to major cigarette companies.
#
# The results of your analysis will be used as part of a major report relating public health and local economics, and will be combined with other studies executed by your colleagues to provide important government advice.
#
# -------------------------------
# As ever, this notebook is **tiered**, meaning you can elect that tier that is right for your confidence and skill level. There are 3 tiers, with tier 1 being the easiest and tier 3 being the hardest.
#
# **1. Sourcing and loading**
# - Load relevant libraries
# - Load the data
# - Explore the data
#
#
# **2. Cleaning, transforming and visualizing**
# - Dropping unwanted columns
# - Nomenclature
# - Type conversions
# - Making a predictor variable `y`
# - Getting summary statistics for `y`
# - Plotting `y`
#
#
# **3. Modelling**
# - Decomposition
#     - Trend
#     - Seasonality
#     - Noise
# - Testing for stationarity with KPSS
# - Making the data stationary
# - The ARIMA Model
#     - Make a function to find the MSE of a single ARIMA model
#     - Make a function to evaluate the different ARIMA models with different p, d, and q values
# - Visualize the results
# - Application: Forecasting
#
# **4. Evaluating and concluding**
# - What is our conclusion?
# - Next steps

# %% [markdown]
# ## 0. Preliminaries
#
# Time series data is just any data displaying how a single variable changes over time. It comes as a collection of metrics typically taken at regular intervals. Common examples of time series data include weekly sales data and daily stock prices. You can also easily acquire time series data from [Google Trends](https://trends.google.com/trends/?geo=US), which shows you how popular certain search terms are, measured in number of Google searches.

# %% [markdown]
# ## 1. Sourcing and Loading
#
# ### 1a. Load relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1b. Load the data
# Call the variable `cigData`.

# %%
cigData = pd.read_csv('/Users/ruhel/Desktop/Python/Springboard/DataScienceGuidedCapstone/Cowboys&CigrettesCaseStudy/CowboyCigsData.csv')

# %% [markdown]
# ### 1c. Explore the data
# We now need to check whether the data conduces to a time series style analysis.

# %%
cigData.shape
# Out:
# (144, 3)

# %%
cigData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  144 non-null    int64
#  1   Time        144 non-null    object
#  2   #CigSales   144 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.5+ KB

# %%
cigData.iloc[1:100:10]
# Out:
#     Unnamed: 0     Time  #CigSales
# 1            1  1949-02    1000118
# 11          11  1949-12    1000118
# 21          21  1950-10    1000133
# 31          31  1951-08    1000199
# 41          41  1952-06    1000218
# 51          51  1953-04    1000235
# 61          61  1954-02    1000188
# 71          71  1954-12    1000229
# 81          81  1955-10    1000274
# 91          91  1956-08    1000405

# %% [markdown]
# Over a million cigarettes sold in the month of January 1949. This certainly is a popular cigarette brand.

# %% [markdown]
# Check out the columns feature of the data. How many columns are there?

# %%
cigData.columns
# Out:
# Index(['Unnamed: 0', 'Time', '#CigSales'], dtype='object')

# %% [markdown]
# Let's check out the data types of our columns.

# %%
cigData.dtypes
# Out:
# Unnamed: 0     int64
# Time          object
# #CigSales      int64
# dtype: object

# %% [markdown]
# Check whether there are any null values.

# %%
cigData.isnull().sum()
# Out:
# Unnamed: 0    0
# Time          0
# #CigSales     0
# dtype: int64

# %% [markdown]
# ## 2. Cleaning, transforming and visualizing

# %% [markdown]
# ### 2a. Dropping unwanted columns
# We need to cut that `Unnamed: 0` column. Delete it here.

# %%
cigData.drop(columns='Unnamed: 0', inplace=True)

# %%
cigData.columns
# Out:
# Index(['Time', '#CigSales'], dtype='object')

# %% [markdown]
# ### 2b. Nomenclature

# %% [markdown]
# We can see that the `Time` column actually has the granularity of months. Change the name of that column to `Month`.

# %%
cigData = cigData.rename(columns={'Time':'Month'})

# %% [markdown]
# Call a head() to check this has worked.

# %%
cigData.head()
# Out:
#      Month  #CigSales
# 0  1949-01    1000112
# 1  1949-02    1000118
# 2  1949-03    1000132
# 3  1949-04    1000129
# 4  1949-05    1000121

# %%
cigData.columns
# Out:
# Index(['Month', '#CigSales'], dtype='object')

# %% [markdown]
# ### 2c. Type conversions

# %% [markdown]
# Now, do time series analysis on a Pandas dataframe is overkill, and is actually counter-productive. It's much more easy to carry out this type of analysis if we convert our data to a series first.
#
# Notice that the `Month` field was an object. Let's type convert the `Month` column to a Python `datetime`, before making that the index.

# %%
cigData['Month'] = pd.to_datetime(cigData['Month'], errors='coerce')
cigData.set_index('Month', inplace=True)

# %%
cigData.head()
# Out:
#             #CigSales
# Month
# 1949-01-01    1000112
# 1949-02-01    1000118
# 1949-03-01    1000132
# 1949-04-01    1000129
# 1949-05-01    1000121

# %% [markdown]
# Perfect!

# %% [markdown]
# ### 2d. Making a predictor variable `y`

# %% [markdown]
# The data is now indexed by date, as time series data ought to be.
#
# Since we want to predict the number of cigarette sales at Cowboy cigarettes, and `y` is typically used to signify a predictor variable, let's create a new variable called `y` and assign the indexed #Passenger column.

# %%
y = cigData['#CigSales']

# %% [markdown]
# Check the type of our new variable.

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 2e. Getting summary statistics for `y`

# %% [markdown]
# Get the summary statistics of our data here.

# %%
cigData.describe()
# Out:
#           #CigSales
# count  1.440000e+02
# mean   1.000280e+06
# std    1.199663e+02
# min    1.000104e+06
# 25%    1.000180e+06
# 50%    1.000266e+06
# 75%    1.000360e+06
# max    1.000622e+06

# %% [markdown]
# Try visualizing the data. A simple `matplotlib` plot should do the trick.

# %% [markdown]
# ### 2f. Plotting `y`

# %%
plt.figure(figsize=(12,8))
y.plot(marker='o', linewidth=1)
plt.title('Cigarette Sales 1949-1960')
plt.ylabel('Cigarette Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Modelling
# ### 3a. Decomposition
# What do you notice from the plot? Take at least `2` minutes to examine the plot, and write down everything you observe.
#
# All done?
#
# We can see that, generally, there is a trend upwards in cigarette sales from at Cowboy Cigarettes. But there are also some striking - and perhaps unexpected - seasonal fluctuations. These seasonal fluctations come in a repeated pattern. Work out when these seasonal fluctuations are happening, and take 2 minutes to hypothesize on their cause here.
#
# What does it mean to *decompose* time series data? It means breaking that data into 3 components:
#
# 1. **Trend**: The overall direction that the data is travelling in (like upwards or downwards)
# 2. **Seasonality**: Cyclical patterns in the data
# 3. **Noise**: The random variation in the data
#
# We can treat these components differently, depending on the question and what's appropriate in the context. They can either be added together in an *additive* model, or multiplied together in a *multiplicative* model.
#
# Make a coffee, take `5` minutes and read [this article](https://medium.com/@sigmundojr/seasonality-in-python-additive-or-multiplicative-model-d4b9cf1f48a7) and think about whether our data would conduce to an additive or multiplicative model here. Write your conclusion down just here:
#
# -------------------------------

# %% [markdown]
# All done? Well, just on the basis of the plot above, it seems our Cowboy Cigarettes data is actually multiplicative.
#
# That's because, as time progresses, the general trend seems to be increasing *at a rate that's also increasing*. We also see that the seasonal fluctuations (the peaks and troughs) get bigger and bigger as time progresses.
#
# Now on the other hand, if the data were simply additive, we could expect the general trend to increase at a *steadily*, and a constant speed; and also for seasonal ups and downs not to increase or decrease in extent over time.
#
# Happily, we can use the `decompose()` function to quantify the component parts described above in our data.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Make a variable called decomposition, and assign it y passed to seasonal_decompose() 
decomposition = seasonal_decompose(y, model='multiplicative', period=12)

# Assiign relavant features of decomposition
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the original data, the trend, the seasonality, and the residuals 
fig, axs = plt.subplots(4,1, figsize=(14,10), sharex=True)

axs[0].plot(y, label='Original', color='blue')
axs[0].legend(loc='best')
axs[0].set_title('Original time series')

axs[1].plot(trend, label='Trend', color='orange')
axs[1].legend(loc='best')
axs[1].set_title('Trend Component')

axs[2].plot(seasonal, label='Seasonal', color='green')
axs[2].legend(loc='best')
axs[2].set_title('Seasonal Component')

axs[3].plot(residual, label='Residual', color='red')
axs[3].legend(loc='best')
axs[3].set_title('Residuals')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3b. Testing for stationarity with KPSS
# As you know, when doing time series analysis we always have to check for stationarity. Imprecisely, a time series dataset is stationary just if its statistical features don't change over time. A little more precisely, a stationary time series dataset will have constant mean, variance, and covariance.
#
# There are many ways to test for stationarity, but one of the most common is the KPSS test. The Null hypothesis of this test is that the time series data in question is stationary; hence, if the *p*-value is less than the significance level (typically 0.05, but we decide) then we reject the Null and infer that the data is not stationary.

# %%
from statsmodels.tsa.stattools import kpss

# Check for level statinarity , regression = 'c'
statistics, p_value, lags, critical_values = kpss(y, regression = 'c')

print('KPSS statistics:', statistics)
print('p_vlaue:', p_value)
print('Lags used:', lags)
print('Critical Values:', critical_values)
# Out:
# KPSS statistics: 1.651312235417082
# p_vlaue: 0.01
# Lags used: 8
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# /var/folders/f3/hdbg9f_j0cn761_jtcpg4pkr0000gn/T/ipykernel_9047/2533662620.py:4: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   statistics, p_value, lags, critical_values = kpss(y, regression = 'c')

# %%
# Check for trend stationarity, regression='ct'
statistics, p_value, lags, critical_values = kpss(y, regression='ct')

print('KPSS Trendn:')
print('KPSS statistics:', statistics)
print('p_vlaue:', p_value)
print('Lags used:', lags)
print('Critical Values:', critical_values)
# Out:
# KPSS Trendn:
# KPSS statistics: 0.09614984853197875
# p_vlaue: 0.1
# Lags used: 4
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# /var/folders/f3/hdbg9f_j0cn761_jtcpg4pkr0000gn/T/ipykernel_9047/2349640709.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistics, p_value, lags, critical_values = kpss(y, regression='ct')

# %% [markdown]
# Since our p-value is less than 0.05, we should reject the Null hypothesis and deduce the non-stationarity of our data.
#
# But our data need to be stationary! So we need to do some transforming.

# %% [markdown]
# ### 3c. Making the data stationary
# Let's recall what it looks like.

# %%
plt.figure(figsize=(10,6))
y.plot(marker='o', linewidth=1)
plt.title('Cigarette Salees 1949-1960')
plt.yticks([1000100, 1000200, 1000300, 1000400, 1000500, 1000600, 1000700],
          ['1000.1K', '1000.2K', '1000.3K', '1000.4K', '1000.5K', '1000.6K', '1000.7K'])
plt.ylabel('Cigarette Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# In our plot, we can see that both the mean and the variance *increase as time progresses*. At the moment, our data has neither a constant mean, nor a constant variance (the covariance, however, seems constant).
#
# One often  used way of getting rid of changing variance is to take the natural log of all the values in our dataset. Let's do this now.

# %%
# Declare a variable called y_log
y_log = np.log(y)
y_log.head()
# Out:
# Month
# 1949-01-01    13.815623
# 1949-02-01    13.815629
# 1949-03-01    13.815643
# 1949-04-01    13.815640
# 1949-05-01    13.815632
# Name: #CigSales, dtype: float64

# %%
print(type(y_log))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# When you plot this, you can see how the variance in our data now remains constant over time.

# %%
plt.figure(figsize=(10,6))
y_log.plot(marker = 'o', linewidth=2)
plt.title('Cigarette Sales-log')
plt.grid(True)
plt.show()

# %% [markdown]
# We now have a constant variance, but we also need a constant mean.
#
# We can do this by *differencing* our data. We difference a time series dataset when we create a new time series comprising the difference between the values of our existing dataset.
#
# Python is powerful, and we can use the `diff()` function to do this. You'll notice there's one less value than our existing dataset (since we're taking the difference between the existing values).

# %%
y_log_diff = y_log.diff()
y_log_diff = y_log_diff.dropna()

# Plot y_log_diff
plt.figure(figsize=(14,6))
y_log_diff.plot(marker='o', color='salmon')
plt.grid(True)
plt.title('Cigarette Sales-log/diff')
plt.show()

# %%
from statsmodels.tsa.stattools import kpss

statistics, p_value, lags, crtical_values = kpss(y_log_diff)

print('KPSS statistics:', statistics)
print('p_vlaue:', p_value)
print('Lags used:', lags)
print('Critical Values:', critical_values)
# Out:
# KPSS statistics: 0.02389767420757056
# p_vlaue: 0.1
# Lags used: 7
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# /var/folders/f3/hdbg9f_j0cn761_jtcpg4pkr0000gn/T/ipykernel_9047/323166133.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistics, p_value, lags, crtical_values = kpss(y_log_diff)

# %% [markdown]
# Our p-value is now greater than 0.05, so we can accept the null hypothesis that our data is stationary.

# %% [markdown]
# ### 3d. The ARIMA model
#
# Recall that ARIMA models are based around the idea that it's possible to predict the next value in a time series by using information about the most recent data points. It also assumes there will be some randomness in our data that can't ever be predicted.
#
# We can find some good parameters for our model using the `sklearn` and `statsmodels` libraries, and in particular `mean_squared_error` and `ARIMA`.

# %%
# Import mean_squared_error and ARIMA
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### 3di. Make a function to find the MSE of a single ARIMA model
# Things get intricate here. Don't worry if you can't do this yourself and need to drop down a Tier.

# %%
def arima_mse(data, order):
    """
    Compute out-of-sample MSE for a single ARIMA order.
    """
    split = int(len(data) * 0.8)
    train, test = data[0:split], data[split:len(data)]

    history = [x for x in train]
    predictions = []

    for i in range(len(test)):
        model = ARIMA(history, order=order)
        model_fit = model.fit()
        pred = model_fit.forecast()[0]  # one-step forecast
        predictions.append(pred)
        history.append(test[i])

    return mean_squared_error(test, predictions)

# %% [markdown]
# #### 3dii. Make a function to evaluate the different ARIMA models with different p, d, and q values

# %%
# Make a function to evaluate different ARIMA models with several different p, d, and q values.

def evaluate_arima_models(dataset, p_values, d_values, q_values):
    """
    Grid search over ARIMA(p,d,q) values to find the best model.
    """
    best_score, best_order = float("inf"), None

    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p, d, q)
                try:
                    mse = arima_mse(dataset, order)
                    print(f"ARIMA{order} MSE={mse}")
                    
                    if mse < best_score:
                        best_score, best_order = mse, order
                except Exception as e:
                    print(f"Failed ARIMA{order}: {e}")
                    continue

    print(f"\nBest ARIMA{best_order} MSE={best_score}")
    return best_order, best_score

# %%
# Now, we choose a couple of values to try for each parameter.

p_values = [x for x in range(0, 3)]
d_values = [x for x in range(0, 3)]
q_values = [x for x in range(0, 3)]

# Finally, we can find the optimum ARIMA model for our data.
import warnings
warnings.filterwarnings('ignore')

best_order, best_mse = evaluate_arima_models(y_log, p_values, d_values, q_values)
print("Best ARIMA model:", best_order)
print("MSE:", best_mse)
# Out:
# ARIMA(0, 0, 0) MSE=0.0000
# ARIMA(0, 0, 1) MSE=0.0000
# ARIMA(0, 0, 2) MSE=0.0000
# ARIMA(0, 1, 0) MSE=0.0000
# ARIMA(0, 1, 1) MSE=0.0000
# ARIMA(0, 1, 2) MSE=0.0000
# ARIMA(0, 2, 0) MSE=0.0000
# ARIMA(0, 2, 1) MSE=0.0000
# ARIMA(0, 2, 2) MSE=0.0000
# ARIMA(1, 0, 0) MSE=0.0000
# ARIMA(1, 0, 1) MSE=0.0000
# ARIMA(1, 0, 2) MSE=0.0000
# ARIMA(1, 1, 0) MSE=0.0000
# ARIMA(1, 1, 1) MSE=0.0000
# ARIMA(1, 1, 2) MSE=0.0000
# ARIMA(1, 2, 0) MSE=0.0000
# ARIMA(1, 2, 1) MSE=0.0000
# ARIMA(1, 2, 2) MSE=0.0000
# ARIMA(2, 0, 0) MSE=0.0000
# ARIMA(2, 0, 1) MSE=0.0000
# ARIMA(2, 0, 2) MSE=0.0000
# ARIMA(2, 1, 0) MSE=0.0000
# ARIMA(2, 1, 1) MSE=0.0000
# ARIMA(2, 1, 2) MSE=0.0000
# ARIMA(2, 2, 0) MSE=0.0000
# ARIMA(2, 2, 1) MSE=0.0000
# ARIMA(2, 2, 2) MSE=0.0000
#
# Best ARIMA(2, 1, 1) MSE=2.2522549151747734e-09
# Best ARIMA model: (2, 1, 1)
# MSE: 2.2522549151747734e-09

# %% [markdown]
# So the best p,d, q, parameters for our ARIMA model are 2, 1, 1 respectively. Now we know this, we can build the model.

# %%
p = 2
d = 1
q = 1

# Fit ARIMA on y_log
best_model = ARIMA(y_log, order=(p,d,q))
best_model_fit = best_model.fit()

# Forecast 24 months
best_model_forecast_log = best_model_fit.forecast(24)

# %% [markdown]
# We can take a look at a summary of the model this library has built around our data.

# %%
print(best_model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              #CigSales   No. Observations:                  144
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                1287.245
# Date:                Mon, 17 Nov 2025   AIC                          -2566.490
# Time:                        17:26:20   BIC                          -2554.639
# Sample:                    01-01-1949   HQIC                         -2561.674
#                          - 12-01-1960
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0575   1.33e-19   7.98e+18      0.000       1.057       1.057
# ar.L2         -0.4391   7.17e-19  -6.12e+17      0.000      -0.439      -0.439
# ma.L1         -0.7080   3.89e-20  -1.82e+19      0.000      -0.708      -0.708
# ...

# %% [markdown]
# ### 3e. Visualize the results
#
# Visualize the original dataset plotted against our model.

# %%
# Call figure and plot

pred_diff = best_model_fit.predict(start=y_log_diff.index[0], end=y_log_diff.index[-1])

plt.figure(figsize=(12, 8))
plt.plot(y_log, label="Actual differenced")
plt.plot(pred_diff, label="Predicted differenced", linestyle="dashed", color='red')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### 3f. Application: Forecasting
#
# We've done well: our model fits pretty closely to our existing data. Let's now use it to forecast what's likely to occur in future.

# %%
# Declare a variable called forecast_period with the amount of months to forecast, and
# create a range of future dates that is the length of the periods you've chosen to forecast
forecast_period = 24
forecasts = np.exp(best_model_forecast_log)
# Create future dates
future_dates = pd.date_range(
                start=y.index[-1] + pd.offsets.MonthBegin(1),
                periods=forecast_period,
                freq='MS'
)

# create a series for easy plotting
forecast_series = pd.Series(forecast, index=future_dates)

# plot actual vs forecast
plt.figure(figsize=(14,8))
plt.plot(y, label='Actual', linewidth=2)
plt.plot(forecast_series, label='Forecast', color='red', linestyle='dashed', linewidth=2)
plt.title('ARIMA Forecast (Next 24 Months)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### The SARIMAX Model
# Although ARIMA models are useful for capturing trends and short-term autocorrelation, they are not designed to handle seasonality. Our dataset *Cowboys&Cigarettes* contains a clear 12-month repeating seasonal pattern, and ARIMA cannot model this structure effectively. SARIMAX extends ARIMA by adding seasonal components, allowing it to model both the long-term trend and the 12-month cycle.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings

warnings.filterwarnings('ignore')

# %%
# SARIMAX Grid search
# We fix d=1 and D=1 because data has trend + yearly seasonality

p = q = range(0,3)
P = Q = range(0,2)
d = D = 1
s = 12

best_aic = float('inf')
best_order = None
best_seasonal_order = None
best_model_fit = None

print('Searching best SARIMAX model...')

for i in p:
    for j in q:
        for I in P:
            for J in Q:
                order = (i,d,j)
                seasonal_order = (I,D,J,s)
                
                try:
                    model = SARIMAX(y_log,
                                   order=order,
                                   seasonal_order=seasonal_order,
                                   enforce_stationarity=False,
                                   enforce_invertibility=False
                                   )
                    model_fit = model.fit(disp=False)
                    aic = model_fit.aic
                    
                    if aic < best_aic:
                        best_aic = aic
                        best_order = order
                        best_seasonal_order = seasonal_order
                        best_model_fit = model_fit
                        
                    print(f"SARIMAX{order}x{seasonal_order} --> AIC{aic}")
                
                except:
                    continue
                    
print("\nBest Model Found:")
print("Non-seasonal order :", best_order)
print("Seasonal order     :", best_seasonal_order)
print("Best AIC           :", best_aic)
# Out:
# Searching best SARIMAX model...
# SARIMAX(0, 1, 0)x(0, 1, 0, 12) --> AIC-2572.319606773418
# SARIMAX(0, 1, 0)x(0, 1, 1, 12) --> AIC-2250.990568116447
# SARIMAX(0, 1, 0)x(1, 1, 0, 12) --> AIC-2336.129276033727
# SARIMAX(0, 1, 0)x(1, 1, 1, 12) --> AIC-2302.5043911053654
# SARIMAX(0, 1, 1)x(0, 1, 0, 12) --> AIC-1265.7705091773064
# SARIMAX(0, 1, 1)x(0, 1, 1, 12) --> AIC-2296.6759092877996
# SARIMAX(0, 1, 1)x(1, 1, 0, 12) --> AIC-2351.418413390951
# SARIMAX(0, 1, 1)x(1, 1, 1, 12) --> AIC-2308.2729745988077
# SARIMAX(0, 1, 2)x(0, 1, 0, 12) --> AIC-2289.0359998999543
# SARIMAX(0, 1, 2)x(0, 1, 1, 12) --> AIC-2275.68546330929
# SARIMAX(0, 1, 2)x(1, 1, 0, 12) --> AIC-2350.260077764074
# SARIMAX(0, 1, 2)x(1, 1, 1, 12) --> AIC-2279.3613738529552
# SARIMAX(1, 1, 0)x(0, 1, 0, 12) --> AIC-2563.349829120404
# SARIMAX(1, 1, 0)x(0, 1, 1, 12) --> AIC-2266.7569307401664
# SARIMAX(1, 1, 0)x(1, 1, 0, 12) --> AIC-2333.795521592418
# SARIMAX(1, 1, 0)x(1, 1, 1, 12) --> AIC-2321.0320895558707
# ...

# %%
# Forecast next 24 months
forecast_period = 24
forecast_log = best_model_fit.forecast(steps=forecast_period)

#convert back to original scale
forecast = np.exp(forecast_log)

# Create future dates
future_dates = pd.date_range(
                start = y.index[-1] + pd.offsets.MonthBegin(1),
                periods = forecast_period,
                freq = 'MS'
)

forecast_series = pd.Series(forecast, index = future_dates)

# Plot actual vs forecast

plt.figure(figsize=(14,8))
plt.plot(y, label='Actual', linewidth=2)
plt.plot(forecast_series, label='Forecast (SARIMAX)', color='red', linestyle='dashed', linewidth=2)

plt.title('SARIMAX Forecast (Next 24 Months)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Evaluating and Concluding
#
# Our model(**ARIMA and SARIMX**) captures the centre of a line that's increasing at a remarkable rate. Cowboy Cigarettes sell more cigarettes in the summer, perhaps due to the good weather, disposable income and time off that people enjoy, and the least in the winter, when people might be spending less and enjoying less free time outdoors.
#
# Remarkably, our models made predictions using just one variable. We can only speculate, however, on the causes of the behaviour predicted by our model. We should also take heed that spikes in data, due to sudden unusual circumstances like wars, are not handled well by ARIMA; and the outbreak of the Vietnam War in the 1960s would likely cause our model some distress.
#
# We could suggest to our employers that, if they are interested in discovering the causes of the cigarette sales trajectory, they execute a regression analysis in addition to the time series one.
